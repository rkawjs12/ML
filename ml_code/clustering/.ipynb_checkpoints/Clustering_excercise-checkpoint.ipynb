# %% [markdown]
# # Clustering

# %%
# %load_ext watermark
# %watermark -a "Sebastian Raschka" -u -d -v -p numpy,pandas,matplotlib,scipy,sklearn

# %% [markdown]
# *The use of `watermark` is optional. You can install this IPython extension via "`pip install watermark`". For more information, please see: https://github.com/rasbt/watermark.*

# %%
from IPython.display import Image
# %matplotlib inline

# %% [markdown]
# # Grouping objects by similarity using k-means

# %% [markdown]
# ## K-means clustering using scikit-learn

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=150, 
                  n_features=2, 
                  centers=3, 
                  cluster_std=0.9,  
                  shuffle=True, 
                  random_state=0)
#n_features=2 변수 2개(구매 특징). 이거 때문에 X에 변수 2개의 array로 생성된다. 
#centers=3 그룹의 갯수 3개이다. 그래서 y에 0,1,2값을 가진 array로 구성된다. 
#cluster_std=0.5 는 산포도 
#shuffle=True 한번 섞어준다.
#위에 있는 함수는 n_samples=150개의 데이터를 만든다.

# %%
print(X,y)
# Out:
# [[ 3.04496116  1.48740102]
#  [ 0.17726291  2.52107051]
#  [ 0.66314914  4.4445014 ]
#  [ 0.17035017  4.65199958]
#  [ 3.06923985 -0.0742747 ]
#  [ 2.08353169  5.38592919]
#  [ 2.35577137  5.62621022]
#  [ 2.63138589 -0.55759678]
#  [-2.59687735  2.46174754]
#  [ 2.31569705  6.01008759]
#  [ 4.00217988  2.10053881]
#  [ 0.54662101  1.96386802]
#  [-2.10059734  2.56033763]
#  [ 0.51758311  3.90952046]
#  [-0.49090843  4.72029136]
#  [-2.37690564  2.54883754]
#  [-1.43895154  3.44254057]
#  [ 1.72300387  0.6822224 ]
#  [-1.64649653  2.64987047]
#  [ 2.01991299 -0.15362049]
#  [ 0.37105568  3.98018948]
#  [ 2.74987902  1.6388174 ]
#  [ 1.25803101  3.53510116]
#  [ 1.10590929  5.61263348]
#  [-1.05794562  2.39967309]
#  [ 2.52621652  0.74327196]
#  [ 2.60793895  1.72764966]
#  [ 1.39536627  2.92116801]
#  [-3.35452003  4.77592584]
#  [ 1.02254573  0.50362562]
#  [-1.64925874  3.94108449]
#  [-2.06448848  2.7037527 ]
#  [-0.81920885  2.49810507]
#  [-1.94414039  3.35121559]
#  [-0.15124575  5.00352865]
#  [ 1.38966082  2.2863768 ]
#  [ 3.73607059  1.71310385]
#  [ 1.48300605  1.50645363]
#  [ 0.40538019  3.97732028]
#  [ 1.29699984  4.93970318]
#  [-1.1677623   0.42254878]
#  [-1.80501569  1.40947884]
#  [-0.16716642  5.17624436]
#  [ 1.736673   -0.3397925 ]
#  [ 2.20527367  1.46919195]
#  [ 2.82641507  0.31174063]
#  [-0.90451914  3.54315649]
#  [ 3.01904924  2.99485822]
#  [-0.92715924  2.50323445]
#  [ 1.83134965  4.16756584]
#  [ 1.66362932  2.56200102]
#  [ 0.01259272  5.25279388]
#  [ 1.16371756  5.18276246]
#  [ 1.68301044  0.22495433]
#  [ 2.6603328   1.26437931]
#  [-1.38604813  3.12684519]
#  [ 0.51654545  3.24121836]
#  [ 3.78591535  2.23012697]
#  [-0.90606767  4.08954387]
#  [ 1.63245158  4.41987195]
#  [-2.95154857  3.4672237 ]
#  [ 0.23341706  3.26896625]
#  [-1.80670157  3.00554241]
#  [-1.54222239  3.25911882]
#  [ 1.13595361  3.94218448]
#  [ 0.50647404  2.87985082]
#  [ 1.09049096  4.66557775]
#  [ 1.2801644   2.61672212]
#  [-1.32142076  4.89204406]
#  [-0.55937309  6.05948518]
#  [ 2.00173069  3.19244409]
#  [ 0.95237555  1.65759034]
#  [ 2.90779429  0.75815458]
#  [-0.07954099  6.05304639]
#  [ 1.12444896  1.51109873]
#  [ 0.6958728   4.35433614]
#  [ 2.03717169  4.14185498]
#  [-2.25893185  1.59810037]
#  [-1.26919469  3.46584171]
#  [ 0.95090607  4.68928601]
#  [ 1.44836813  0.92631116]
#  [ 1.33219882  0.27706886]
#  [ 0.03257241  3.02577118]
#  [ 1.37574699  4.60409422]
#  [ 2.32368188  2.09141097]
#  [ 4.20009782  1.7476952 ]
#  [ 2.88404046  1.18451855]
#  [-2.01547934  3.2923273 ]
#  [-2.46763204  4.00791302]
#  [ 2.61797583 -0.54418823]
#  [ 2.3940505  -0.09179705]
#  [ 1.01745274  4.13532186]
#  [ 0.71313569  1.29311619]
#  [ 0.61341083  5.40398789]
#  [ 1.43015645  0.76299257]
#  [ 2.67110571  3.09080417]
#  [-2.38725451  2.60649866]
#  [-2.5674682   3.62096055]
#  [ 0.87095085  0.48223752]
#  [ 1.99385008  2.43967211]
#  [ 1.36234305  1.38298793]
#  [ 2.90974625  0.97645978]
#  [-2.70277818  4.41019987]
#  [ 1.96666025  0.3005332 ]
#  [ 1.06132252  0.94461223]
#  [ 1.11572276  4.6441336 ]
#  [-1.88640814  3.25093256]
#  [ 2.32094124  4.11914489]
#  [ 0.88337311  4.67332598]
#  [-0.07236478  5.11453117]
#  [-1.14327116  3.52709949]
#  [ 0.62767594  4.03171485]
#  [ 1.64528827  0.9133949 ]
#  [-1.05540209  2.99746214]
#  [ 0.9857201   5.91107077]
#  [-3.26955584  3.087783  ]
#  [ 1.03613558  4.57601204]
#  [ 1.75426266  3.63583881]
#  [-1.08253641  2.81338872]
#  [-2.06358665  2.87057169]
#  [ 0.19255264  3.78282263]
#  [ 3.12449433  1.18291201]
#  [ 0.15970155  4.35053818]
#  [-0.47623798  4.11232108]
#  [ 1.60703832  2.63424251]
#  [ 1.81406449  1.61987442]
#  [-1.54879753  2.25365444]
#  [ 1.38498818  0.15386898]
#  [-2.91362133  2.97481806]
#  [-1.39914617  2.63048669]
#  [-1.27497187  2.82954691]
#  [-0.707743    3.20337866]
#  [ 0.8916963   1.13800944]
#  [-1.63325165  2.30572188]
#  [-1.6263906   3.8360377 ]
#  [-0.18186792  1.05489574]
#  [ 0.24443842  2.75013299]
#  [-2.11407174  2.56602422]
#  [ 1.23372752  1.90297832]
#  [-2.09218282  2.48495785]
#  [ 1.66120403  4.41329484]
#  [ 1.33837756  3.68745825]
#  [ 1.47601096 -1.10339918]
#  [ 2.57419926  0.71019478]
#  [-0.4898056   3.88953899]
#  [-2.80855883  2.47389437]
#  [-2.14974888  4.30062161]
#  [-2.17994165  1.6728547 ]
#  [ 2.41167356 -0.0860917 ]
#  [ 1.15507371 -0.49263033]] [1 0 0 0 1 0 0 1 2 0 1 2 2 0 0 2 2 1 2 1 0 1 0 0 2 1 1 0 2 1 2 2 2 2 0 1 1
#  1 0 0 2 2 0 1 1 1 2 0 2 0 1 0 0 1 1 2 0 1 2 0 2 2 2 2 0 2 0 1 0 0 0 1 1 0
#  1 0 0 2 2 0 1 1 0 0 1 1 1 2 2 1 1 0 1 0 1 0 2 2 1 1 1 1 2 1 1 0 2 0 0 0 2
#  0 1 2 0 2 0 0 2 2 0 1 0 0 1 1 2 1 2 2 2 2 1 2 2 2 0 2 1 2 0 0 1 1 2 2 2 2
#  1 1]

# %%
import matplotlib.pyplot as plt

plt.scatter(X[:, 0], X[:, 1], 
            c='white', marker='o', edgecolor='black', s=50)
plt.grid()
plt.tight_layout()
#plt.savefig('images/11_01.png', dpi=300)
plt.show()

# %%
from sklearn.cluster import KMeans

km = KMeans(n_clusters=3, 
            init='random', #처음에 점을 찍어주는 위치를 랜덤으로 준다는 말
            max_iter = 300, #중심점을 찾는 과정을 최대 300번까지 한다고 설정한 것.
            random_state=0)
# km.fit(X)
# y_km = km.predict(X)

y_km = km.fit_predict(X)

# %%
print(y_km)
# Out:
# [1 0 0 0 1 0 0 1 2 0 1 1 2 0 0 2 2 1 2 1 0 1 0 0 2 1 1 0 2 1 2 2 2 2 0 1 1
#  1 0 0 2 2 0 1 1 1 2 1 2 0 1 0 0 1 1 2 0 1 2 0 2 0 2 2 0 0 0 1 2 0 0 1 1 0
#  1 0 0 2 2 0 1 1 0 0 1 1 1 2 2 1 1 0 1 0 1 1 2 2 1 1 1 1 2 1 1 0 2 0 0 0 2
#  0 1 2 0 2 0 0 2 2 0 1 0 0 1 1 2 1 2 2 2 2 1 2 2 1 0 2 1 2 0 0 1 1 0 2 2 2
#  1 1]

# %%
X[y_km==1][:,0]
#y_km==1을 하면 1이면 참, 다른 수면 거짓으로 값이 나오는 array를 return하게 되는데,
#X의 행의 값과 크기가 같아서, y_km==1이 True인 행의 0번째 열이 리턴된다.
#그 결과 아래와 같은 결과가 나타난다.
# Out:
# array([ 3.04496116,  3.06923985,  2.63138589,  4.00217988,  0.54662101,
#         1.72300387,  2.01991299,  2.74987902,  2.52621652,  2.60793895,
#         1.02254573,  1.38966082,  3.73607059,  1.48300605,  1.736673  ,
#         2.20527367,  2.82641507,  3.01904924,  1.66362932,  1.68301044,
#         2.6603328 ,  3.78591535,  1.2801644 ,  0.95237555,  2.90779429,
#         1.12444896,  1.44836813,  1.33219882,  2.32368188,  4.20009782,
#         2.88404046,  2.61797583,  2.3940505 ,  0.71313569,  1.43015645,
#         2.67110571,  0.87095085,  1.99385008,  1.36234305,  2.90974625,
#         1.96666025,  1.06132252,  1.64528827,  3.12449433,  1.60703832,
#         1.81406449,  1.38498818,  0.8916963 , -0.18186792,  1.23372752,
#         1.47601096,  2.57419926,  2.41167356,  1.15507371])

# %%
X[y_km == 0, 0]
# X[y_km == 0, 0]에서 y_km == 0는 참과 거짓으로 나오는데, 참인 것만 해당하는 것을 프린트한다.
# Out:
# array([ 0.17726291,  0.66314914,  0.17035017,  2.08353169,  2.35577137,
#         2.31569705,  0.51758311, -0.49090843,  0.37105568,  1.25803101,
#         1.10590929,  1.39536627, -0.15124575,  0.40538019,  1.29699984,
#        -0.16716642,  1.83134965,  0.01259272,  1.16371756,  0.51654545,
#         1.63245158,  0.23341706,  1.13595361,  0.50647404,  1.09049096,
#        -0.55937309,  2.00173069, -0.07954099,  0.6958728 ,  2.03717169,
#         0.95090607,  0.03257241,  1.37574699,  1.01745274,  0.61341083,
#         1.11572276,  2.32094124,  0.88337311, -0.07236478,  0.62767594,
#         0.9857201 ,  1.03613558,  1.75426266,  0.19255264,  0.15970155,
#        -0.47623798,  0.24443842,  1.66120403,  1.33837756, -0.4898056 ])

# %%
X[y_km == 1, 0]
#X[y_km==1][:.0]과 같은 문장이다
# Out:
# array([ 3.04496116,  3.06923985,  2.63138589,  4.00217988,  0.54662101,
#         1.72300387,  2.01991299,  2.74987902,  2.52621652,  2.60793895,
#         1.02254573,  1.38966082,  3.73607059,  1.48300605,  1.736673  ,
#         2.20527367,  2.82641507,  3.01904924,  1.66362932,  1.68301044,
#         2.6603328 ,  3.78591535,  1.2801644 ,  0.95237555,  2.90779429,
#         1.12444896,  1.44836813,  1.33219882,  2.32368188,  4.20009782,
#         2.88404046,  2.61797583,  2.3940505 ,  0.71313569,  1.43015645,
#         2.67110571,  0.87095085,  1.99385008,  1.36234305,  2.90974625,
#         1.96666025,  1.06132252,  1.64528827,  3.12449433,  1.60703832,
#         1.81406449,  1.38498818,  0.8916963 , -0.18186792,  1.23372752,
#         1.47601096,  2.57419926,  2.41167356,  1.15507371])

# %%
print(km.cluster_centers_)
#cluster_centers_는 군집화된 곳의 중심점을 나타내는 것이다.
# Out:
# [[ 0.81594814  4.37575595]
#  [ 2.03173659  1.10595459]
#  [-1.8344735   3.0028892 ]]

# %%
plt.scatter(X[y_km == 0, 0],
            X[y_km == 0, 1],
            s=50, 
            #s는 사이즈를 의미한다.
            c='lightgreen',
            marker='s', edgecolor='black',
            label='cluster 1')
plt.scatter(X[y_km == 1, 0],
            X[y_km == 1, 1],
            s=50, c='orange',
            marker='o', edgecolor='black',
            label='cluster 2')
plt.scatter(X[y_km == 2, 0],
            X[y_km == 2, 1],
            s=50, c='lightblue',
            marker='v', edgecolor='black',
            label='cluster 3')
plt.scatter(km.cluster_centers_[:, 0],
            km.cluster_centers_[:, 1],
            s=250, marker='*',
            c='red', edgecolor='black',
            label='centroids')
plt.legend(scatterpoints=1)
plt.grid()
plt.tight_layout()
#plt.savefig('images/11_02.png', dpi=300)
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# ## Using the elbow method to find the optimal number of clusters

# %%
print('Distortion: %.2f' % km.inertia_)
# Out:
# Distortion: 221.73

# %%
# kmeans++ - 초기의 센트로이드를 가능한 멀리 두는 것, 
# 고전적 kmeans 보다 나은 성과
# inertia_ : 군집내 SSE
#SSE는 Distortion와 같은 의미로, 클러스터(그룹)의 무게중심에서 해당 클러스터의 점들을과의 거리 평균을 의미한다.

distortions = []
for i in range(1, 11):
    km = KMeans(n_clusters=i, 
                init='random', 
                random_state=0)
    km.fit(X)
    distortions.append(km.inertia_)

plt.plot(range(1, 11), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
#Distortion은 클러스터의 무게중심에서 해당 클러스터의 점들을과의 거리 평균을 의미한다. 
plt.tight_layout()
#plt.savefig('images/11_03.png', dpi=300)
plt.show()

# %%
from sklearn.cluster import KMeans

km = KMeans(n_clusters=3, 
            init='k-means++', 
            max_iter = 300,
            random_state=0)

y_km = km.fit_predict(X)
#km.fit_predict(X) 이 함수는 fit과 predict를 동시에 하는 함수이다.

# %%
plt.scatter(X[y_km == 0, 0],
            X[y_km == 0, 1],
            s=50, c='lightgreen',
            marker='s', edgecolor='black',
            label='cluster 1')
plt.scatter(X[y_km == 1, 0],
            X[y_km == 1, 1],
            s=50, c='orange',
            marker='o', edgecolor='black',
            label='cluster 2')
plt.scatter(X[y_km == 2, 0],
            X[y_km == 2, 1],
            s=50, c='lightblue',
            marker='v', edgecolor='black',
            label='cluster 3')
plt.scatter(km.cluster_centers_[:, 0],
            km.cluster_centers_[:, 1],
            s=250, marker='*',
            c='red', edgecolor='black',
            label='centroids')
plt.legend(scatterpoints=1)
plt.grid()
plt.tight_layout()
#plt.savefig('images/11_02.png', dpi=300)
plt.show()

# %%
# kmeans++ - 초기의 센트로이드를 가능한 멀리 두는 것, 고전적 kmeans 보다 나은 성과
# inertia_ : 군집내 SSE

distortions = []
for i in range(1, 11):
    km = KMeans(n_clusters=i, 
                init='k-means++', 
                random_state=0)
    km.fit(X)
    distortions.append(km.inertia_)
plt.plot(range(1, 11), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.tight_layout()
#plt.savefig('images/11_03.png', dpi=300)
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# ## silhouette
# * 군집 내 샘플들이 얼마나 결합력 있게 그룹핑이 되었는지
# * a - 샘플의 군집 내의 모든 점들과의 평균거리, 군집내 응집력
# * a값이 작으면 군집 내의 모든 점들과의 평균거리가 작다는 의미로, 군집내 응집력이 크다는 의미이다.
# * b - 샘플과 가장 가까운 군집의 모든 샘플들과의 평균거리, 군집 분리력
# * b값이 커지면 가까운 군집의 모든 샘플들과의 평균거리가 크다는 의미로 군집 분리력이 크다는 의미.
# * silhouette = (b-a)/max(b,a)
# * silhouette = (b-a)/max(b,a)의 값이 0에 가까울 수 록 분류가 잘됬다.

# %%
import numpy as np
from matplotlib import cm
from sklearn.metrics import silhouette_samples

km = KMeans(n_clusters=3, 
            init='k-means++', 
            random_state=0)
y_km = km.fit_predict(X)
# print(X[:5])
# print(y_km[:5])

cluster_labels = np.unique(y_km)
#print(cluster_labels)
# n_clusters = cluster_labels.shape[0]
# print(n_clusters)

silhouette_vals = silhouette_samples(X, y_km, metric='euclidean')
#y_km는 계산한 결과 각 점들이 어떠한 그룹에 속하는 지에 대한 값이 있다.
#metric='euclidean' 유클리디안 거리계산방법으로 한다는 것을 의미한다.
#silhouette_samples는 silhouette을 계산하는 함수이다.

print(len(silhouette_vals))
print(silhouette_vals)
y_ax_lower, y_ax_upper = 0, 0

yticks = []
# Out:
# [0 1 2]
# 150
# [0.57302739 0.0336201  0.63539687 0.5322823  0.6175984  0.56748969
#  0.5238484  0.61281883 0.67384579 0.51684342 0.39047601 0.2034373
#  0.70189989 0.55345567 0.27311535 0.69335103 0.57952583 0.66269011
#  0.67548418 0.64921615 0.52850675 0.56646327 0.49143789 0.5946217
#  0.53759575 0.66704327 0.55285653 0.15372485 0.41738997 0.58372191
#  0.50433625 0.70614494 0.45617863 0.66593549 0.44043878 0.24732336
#  0.47677899 0.55014601 0.53778559 0.6598369  0.17747646 0.5440772
#  0.43578619 0.62675237 0.60419774 0.64888534 0.34461124 0.12937468
#  0.4978759  0.55057238 0.14462791 0.48441614 0.64042235 0.65727657
#  0.6269336  0.61427326 0.39218955 0.37896396 0.15238753 0.62201858
#  0.61599236 0.29774255 0.68930225 0.63192673 0.62128408 0.28318621
#  0.67351379 0.00278062 0.09946057 0.29964277 0.16458402 0.41916526
#  0.64373826 0.40749501 0.49431046 0.63610041 0.5004429  0.59707169
#  0.52611687 0.66679007 0.62955116 0.63112841 0.11243702 0.67083187
#  0.44959661 0.4276471  0.62219121 0.67613831 0.56253677 0.61433064
#  0.65274481 0.6485182  0.45529966 0.58113747 0.6374011  0.0297804
#  0.69512911 0.62415158 0.54671924 0.27456958 0.56002456 0.63534878
#  0.48478962 0.67034867 0.57527414 0.67434524 0.67529232 0.42748384
#  0.66208871 0.46608776 0.46471596 0.59434351 0.64745556 0.52413652
#  0.55422958 0.60857068 0.67256229 0.42992641 0.54809502 0.70534769
#  0.42476626 0.60122547 0.50936254 0.14015421 0.08200943 0.5562538
#  0.63312659 0.63255382 0.6498323  0.63452911 0.60623541 0.31925547
#  0.52180414 0.64981531 0.52821235 0.07631249 0.13856887 0.70224429
#  0.39213259 0.69647665 0.616393   0.52948687 0.53079076 0.6658735
#  0.04965806 0.65611328 0.48193062 0.60578916 0.65266543 0.54905848]

# %%
np.mean(silhouette_samples(X, y_km, metric='euclidean'))
# Out:
# 0.5100426184430671

# %%
plt.plot(range(len(silhouette_vals)), sorted(silhouette_vals))
#아래의 그래프를 그리는 이유는 예를 들면, 
#최종값이 0.8인 그래프에서 3개가 있는데, 그래프의 모습이 다르다면, 골고루 있는지, 한쪽에만 쏠려있는지 등을 알 수 있어서 그래프를 그린다.

# %%
clist = ['g','b','y']
for i, c in enumerate(cluster_labels):
    c_silhouette_vals = silhouette_vals[y_km == c]
    c_silhouette_vals.sort()
    y_ax_upper += len(c_silhouette_vals)
#     color = cm.jet(float(i) / n_clusters)
    plt.barh(range(y_ax_lower, y_ax_upper), c_silhouette_vals, \
             height=1.0, edgecolor='none', color=clist[i])
#그래프 그리려고 하는거다 y_ax_lower, y_ax_upper

    yticks.append((y_ax_lower + y_ax_upper) / 2.)
    y_ax_lower += len(c_silhouette_vals)
    
silhouette_avg = np.mean(silhouette_vals)
plt.axvline(silhouette_avg, color="red", linestyle="--") 

plt.yticks(yticks, cluster_labels + 1)
plt.ylabel('Cluster')
plt.xlabel('Silhouette coefficient')

plt.tight_layout()
#plt.savefig('images/11_04.png', dpi=300)
plt.show()

# %% [markdown]
# Comparison to "bad" clustering:

# %%
km = KMeans(n_clusters=2,
            init='k-means++',
            n_init=10,
            max_iter=300,
            tol=1e-04,
            random_state=0)
y_km = km.fit_predict(X)

plt.scatter(X[y_km == 0, 0],
            X[y_km == 0, 1],
            s=50,
            c='lightgreen',
            edgecolor='black',
            marker='s',
            label='cluster 1')
plt.scatter(X[y_km == 1, 0],
            X[y_km == 1, 1],
            s=50,
            c='orange',
            edgecolor='black',
            marker='o',
            label='cluster 2')

plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1],
            s=500, marker='*', c='red')#, label='centroids')
plt.legend()
plt.grid()
plt.tight_layout()
#plt.savefig('images/11_05.png', dpi=300)
plt.show()

# %%
cluster_labels = np.unique(y_km)
n_clusters = cluster_labels.shape[0]
silhouette_vals = silhouette_samples(X, y_km, metric='euclidean')
y_ax_lower, y_ax_upper = 0, 0
yticks = []
colorlist=['g','b']
for i, c in enumerate(cluster_labels):
    c_silhouette_vals = silhouette_vals[y_km == c]
    c_silhouette_vals.sort()
    y_ax_upper += len(c_silhouette_vals)
#     color = cm.jet(float(i) / n_clusters)b
    plt.barh(range(y_ax_lower, y_ax_upper), c_silhouette_vals, height=1.0, 
             edgecolor='none', color=colorlist[i])

    yticks.append((y_ax_lower + y_ax_upper) / 2.)
    y_ax_lower += len(c_silhouette_vals)
    
silhouette_avg = np.mean(silhouette_vals)
plt.axvline(silhouette_avg, color="red", linestyle="--") 

plt.yticks(yticks, cluster_labels + 1)
plt.ylabel('Cluster')
plt.xlabel('Silhouette coefficient')

plt.tight_layout()
#plt.savefig('images/11_06.png', dpi=300)
plt.show()

# %%
# <문제> 최적의 클러터링 갯수를 silhouette 기반으로 확인하시오.
silhouette_list = []

for i in range(2,11):   
    km = KMeans(n_clusters=i,
                init='k-means++',
                max_iter=300,
                random_state=0)
    
    y_km = km.fit_predict(X)
    
    silhouette_vals = silhouette_samples(X, y_km, metric='euclidean')
    silhouette_avg = np.mean(silhouette_vals)
    silhouette_list.append(silhouette_avg)
    
plt.plot(range(2,11), silhouette_list)

print(np.argmax(silhouette_list)+2)
# Out:
# 3

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # Hierachical Clustering - Agglomerative Clustering
# 1. 모든 샘플들의 거리 행렬을 계산
# 2. 한 계체 군집으로 개별 관측치를 표시한다
# 3. 가장 멀리있는 개체들의 거리에 기반하여 가장 가까운 두 개의 군집을 합친다
# 4. 유사도 행렬을 업데이트한다.
# 5. 하나의 군집만 남을 때까지 반복한다
#
# * ward - 모든 클러스터 내의 분산을 가장 작게 증가시키는 두 클러스터를 합칩니다.
# * average - 클러스터 사이의 평균 거리가 가장 짧은 두 클러스터를 합칩니다.
# * complete - 클러스터 포인트 사이의 최대 거리가 가장 짧은 두 클러스터를 합칩니다.

# %%
import mglearn

# %%
import matplotlib.font_manager as fm
# path = '‪C:\\Windows\\Fonts\\ALGER.TTF'
# fontprop = fm.FontProperties(fname=path, size=18)

mglearn.plots.plot_agglomerative_algorithm()

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
# %matplotlib inline

# import matplotlib.font_manager as fm
# path = '‪C:\\Windows\\Fonts\\ALGER.TTF'
# fontprop = fm.FontProperties(fname=path, size=18)

X, y = make_blobs(random_state=1)

agg = AgglomerativeClustering(n_clusters=5)
assignment = agg.fit_predict(X)
print(assignment[:20])

mglearn.discrete_scatter(X[:, 0], X[:,1], assignment)
plt.legend(['클러스터 0', '클러스터 1', '클러스터 2'], loc='best')
plt.xlabel('특성 0')
plt.ylabel('특성 1')
# Out:
# [3 0 0 0 2 4 4 0 1 1 0 0 2 1 2 4 4 1 0 0]
# Text(0, 0.5, '특성 1')

# %%
mglearn.plots.plot_agglomerative()

# %%
from scipy.cluster.hierarchy import dendrogram, ward

linkage_array = ward(X) # 거리 정보를 배열을 반환

row_dendr = dendrogram(linkage_array, # dendrogram을 그림
                       labels=y,
                       )
plt.tight_layout()
plt.ylabel('Euclidean distance')
plt.show()

# %% [markdown]
# ## Grouping clusters in bottom-up fashion

# %%
import pandas as pd
import numpy as np

np.random.seed(123)

variables = ['X', 'Y', 'Z']
labels = ['ID_0', 'ID_1', 'ID_2', 'ID_3', 'ID_4']

X = np.random.random_sample([5, 3])*10
df = pd.DataFrame(X, columns=variables, index=labels)
df
# Out:
#              X         Y         Z
# ID_0  6.964692  2.861393  2.268515
# ID_1  5.513148  7.194690  4.231065
# ID_2  9.807642  6.848297  4.809319
# ID_3  3.921175  3.431780  7.290497
# ID_4  4.385722  0.596779  3.980443

# %% [markdown]
# <br>

# %% [markdown]
# <br>

# %% [markdown]
# ## Applying agglomerative clustering via scikit-learn

# %%
from sklearn.cluster import AgglomerativeClustering

ac = AgglomerativeClustering(n_clusters=3, 
                             affinity='euclidean', 
                             linkage='complete')
labels = ac.fit_predict(X)
print('Cluster labels: %s' % labels)
# Out:
# Cluster labels: [1 0 0 2 1]

# %%
ac = AgglomerativeClustering(n_clusters=5, 
                             affinity='euclidean', 
                             linkage='complete')
labels = ac.fit_predict(X)
print('Cluster labels: %s' % labels)
# Out:
# Cluster labels: [4 3 1 2 0]

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # Locating regions of high density via DBSCAN
# ## 밀도기반 클러스터링
# * 밀도 - 특정반지름 e 내에 점들의 수
# * 설정한 이웃 점의 개수(MinPts)가 설정한 반지름 e 내에 떨어진다면 그점은 중심점
# * 경계점 - e 내에서 설정한 이웃 점의 개수(MinPts) 보다 더 작은 수의 이웃을 갖는 점이지만, 중심점으로 부터 반지름 e 내에 위치
# * 잡음점 - 중심점도 경계점도 아닌 다른 모든 점들. 아주 멀리 벗어나서 군집에 들어가지 않는 점
# * 중심점이나 중심점들이 연결된 그룹에 대해 군집을 형성, e보다 떨어져 있지 않다면 중심점들은 연결된다 (밀집지역)
# * 각각의 경계점을 자신의 중심점이 포함되는 군집에 할당
# * 장점 - 군집의 모양에 대한 가정이 불필요, 각각의 점을 군집에 할당할 필요 없음, 잡음의 제거가 쉽다
# * 단점 - 차원(피쳐수)이 증가하면 부정적 영향
# * 초기에 random한 값으로 시작, 밀집지역 합쳐나감, 중복되는 경계점은 먼저 방문한 중심점에 할당

# %%
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=200, noise=0.05, random_state=0)
plt.scatter(X[:, 0], X[:, 1])
plt.tight_layout()
#plt.savefig('images/11_14.png', dpi=300)
plt.show()

# %%
from sklearn.cluster import DBSCAN
# from sklearn.metrics.cluster import silhouette_score

db = DBSCAN(eps=0.2, min_samples=5, metric='euclidean')
y_db = db.fit_predict(X)

plt.scatter(X[y_db == 0][:, 0], X[y_db == 0][:, 1],
            c='lightblue', marker='o', s=40,
            edgecolor='black', label='cluster 1')

plt.scatter(X[y_db == 1][:, 0], X[y_db == 1][:, 1],
            c='red', marker='s', s=40,
            edgecolor='black', label='cluster 2')

plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# K-means and hierarchical clustering:

# %%
# from sklearn.metrics.cluster import silhouette_score
# f, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 3))

km = KMeans(n_clusters=2, random_state=0)
y_km = km.fit_predict(X)
# print(silhouette_score(X, y_km))

plt.scatter(X[y_km == 0, 0], X[y_km == 0, 1],
            edgecolor='black',
            c='lightblue', marker='o', s=40, label='cluster 1')
plt.scatter(X[y_km == 1, 0], X[y_km == 1, 1],
            edgecolor='black',
            c='red', marker='s', s=40, label='cluster 2')
plt.title('K-means clustering')
# Out:
# Text(0.5, 1.0, 'K-means clustering')

# %%
# from sklearn.metrics.cluster import silhouette_score
ac = AgglomerativeClustering(n_clusters=2,
                             affinity='euclidean',
                             linkage='ward')
y_ac = ac.fit_predict(X)
# print(silhouette_score(X, y_ac))

plt.scatter(X[y_ac == 0, 0], X[y_ac == 0, 1], c='lightblue',
            edgecolor='black',
            marker='o', s=40, label='cluster 1')
plt.scatter(X[y_ac == 1, 0], X[y_ac == 1, 1], c='red',
            edgecolor='black',
            marker='s', s=40, label='cluster 2')
plt.title('Agglomerative clustering')

plt.legend()
plt.tight_layout()
# plt.savefig('images/11_15.png', dpi=300)
plt.show()

# %% [markdown]
# Density-based clustering:

# %%
from sklearn.metrics.cluster import silhouette_score
from sklearn.datasets import make_moons
from sklearn.preprocessing import StandardScaler
import numpy as np
import mglearn
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN




X, y = make_moons(n_samples=200, noise=0.05, random_state=0)

# 평균이 0, 분산이 1이 되도록 데이터의 스케일을 조정합니다
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)

fig, axes = plt.subplots(1, 4, figsize=(15, 3),
                         subplot_kw={'xticks': (), 'yticks': ()})

# 비교를 위해 무작위로 클러스터 할당을 합니다
random_state = np.random.RandomState(seed=0)
random_clusters = random_state.randint(low=0, high=2, size=len(X))

# 무작위 할당한 클러스터를 그립니다
axes[0].scatter(X_scaled[:, 0], X_scaled[:, 1], c=random_clusters,
                cmap=mglearn.cm3, s=60, edgecolors='black')
axes[0].set_title("무작위 할당: {:.2f}".format(
        silhouette_score(X_scaled, random_clusters)))

algorithms = [KMeans(n_clusters=2), AgglomerativeClustering(n_clusters=2),
              DBSCAN()]

for ax, algorithm in zip(axes[1:], algorithms):
    clusters = algorithm.fit_predict(X_scaled)
    # 클러스터 할당과 클러스터 중심을 그립니다
    ax.scatter(X_scaled[:, 0], X_scaled[:, 1], c=clusters, cmap=mglearn.cm3,
               s=60, edgecolors='black')
    ax.set_title("{} : {:.2f}".format(algorithm.__class__.__name__,
                                      silhouette_score(X_scaled, clusters)))
